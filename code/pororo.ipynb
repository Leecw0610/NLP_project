# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\user\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.21.5)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (4.8.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\user\anaconda3\lib\site-packages (from konlpy) (1.4.1)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from JPype1>=0.7.0->konlpy) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging->JPype1>=0.7.0->konlpy) (3.0.4)

# %%
# !pip install git+https://github.com/kakaobrain/pororo.git
# Out:
# Collecting git+https://github.com/kakaobrain/pororo.git
#   Cloning https://github.com/kakaobrain/pororo.git to c:\users\user\appdata\local\temp\pip-req-build-7d8441ad
#   Resolved https://github.com/kakaobrain/pororo.git to commit 7d05a75e8062b00e6b65364b8ec6c52b6293ab07
#   Running command git clone -q https://github.com/kakaobrain/pororo.git 'C:\Users\user\AppData\Local\Temp\pip-req-build-7d8441ad'
# ERROR: Could not find a version that satisfies the requirement torch==1.6.0 (from pororo) (from versions: 1.7.1, 1.8.0, 1.8.1, 1.9.0, 1.9.1, 1.10.0, 1.10.1, 1.10.2, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1)
# ERROR: No matching distribution found for torch==1.6.0

# %%
# !pip install python-mecab-ko
# Out:
# Requirement already satisfied: python-mecab-ko in c:\users\user\anaconda3\lib\site-packages (1.3.3)
# Requirement already satisfied: python-mecab-ko-dic in c:\users\user\anaconda3\lib\site-packages (from python-mecab-ko) (2.1.1.post2)

# %%
from pororo import Pororo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\user\Desktop\Python\Project\Project3\lyrics_recommend\pororo.ipynb 셀 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Python/Project/Project3/lyrics_recommend/pororo.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> from pororo import Pororo
#
# ModuleNotFoundError: No module named 'pororo'

# %%
lyric = "숨을 크게 쉬어봐요 당신의 가슴 양쪽이 저리게 조금은 아파올 때까지 숨을 더 뱉어봐요 당신의 안에 남은 게 없다고 느껴질 때까지 숨이 벅차올라도 괜찮아요 아무도 그댈 탓하진 않아 가끔은 실수해도 돼 누구든 그랬으니까 괜찮다는 말 말뿐인 위로지만 누군가의 한숨 그 무거운 숨을 내가 어떻게 헤아릴 수가 있을까요 당신의 한숨 그 깊일 이해할 순 없겠지만 괜찮아요 내가 안아줄게요  숨이 벅차올라도 괜찮아요 아무도 그댈 탓하진 않아 가끔은 실수해도 돼  누구든 그랬으니까 괜찮다는 말 말뿐인 위로지만 누군가의 한숨 그 무거운 숨을 내가 어떻게 헤아릴 수가 있을까요 당신의 한숨 그 깊일 이해할 순 없겠지만 괜찮아요 내가 안아줄게요 남들 눈엔 힘 빠지는 한숨으로 보일진 몰라도 나는 알고 있죠 작은 한숨 내뱉기도 어려운 하루를 보냈단 걸 이제 다른 생각은 마요 깊이 숨을 쉬어봐요 그대로 내뱉어요 누군가의 한숨 그 무거운 숨을 내가 어떻게 헤아릴 수가 있을까요 당신의 한숨 그 깊일 이해할 순 없겠지만 괜찮아요 내가 안아줄게요 정말 수고했어요"

# %%
abs_summ = Pororo(task="text_summarization", lang="ko", model="abstractive")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.38k [00:00<?, ?B/s]
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Downloading (…)okenizer_config.json:   0%|          | 0.00/337 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.05M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/109 [00:00<?, ?B/s]

# %%
abs_summ(
    lyric,
    beam=5, 
    len_penalty=0.6,
    no_repeat_ngram_size=3,
    top_k=50,
    top_p=0.7
)
# Out:
# '아무도다는 말 말뿐인 위로지만 누군가의 한숨 그 무거운 숨을 내가 어떻게 헤아릴 수 있을까요 힘들게 해도 괜찮아요 내가 안아줄게요 정말 수고했어요'

# %%
abs_summ = Pororo(task="text_summarization", lang="ko", model="bullet")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\user\Desktop\Python\Project\Project3\lyrics_recommend\pororo.ipynb 셀 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/user/Desktop/Python/Project/Project3/lyrics_recommend/pororo.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> abs_summ = Pororo(task="text_summarization", lang="ko", model="bullet")
#
# NameError: name 'Pororo' is not defined

# %%
abs_summ(
    lyric,
    beam=5, 
    len_penalty=0.6,
    no_repeat_ngram_size=3,
    top_k=50,
    top_p=0.7
)
